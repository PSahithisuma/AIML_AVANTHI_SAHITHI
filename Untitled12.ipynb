# %% [markdown]
# <a href="https://colab.research.google.com/github/PSahithisuma/AIML_AVANTHI_SAHITHI/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/archive (1).zip')
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
X=df.drop('diabetes',axis='columns')
y=df['diabetes']
X
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                   0             0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
pd.crosstab(df.heartrate,df.glucose).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-6ce61c2fc047> in <cell line: 1>()
# ----> 1 pd.crosstab(df.heartrate,df.glucose).plot(kind='bar')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'heartrate'

# %%
plt.scatter(df.age,df.education,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['education']],df.male,train_size=0.4)

# %%
X_test
# Out:
#       education
# 2827        1.0
# 2732        2.0
# 782         NaN
# 1506        3.0
# 3859        1.0
# ...         ...
# 1039        2.0
# 4039        1.0
# 1328        2.0
# 139         4.0
# 2806        1.0
#
# [848 rows x 1 columns]

# %%
X_test
# Out:
#       education
# 1523        2.0
# 1990        1.0
# 915         1.0
# 564         4.0
# 458         2.0
# ...         ...
# 2542        NaN
# 3735        1.0
# 1597        2.0
# 2369        2.0
# 802         1.0
#
# [2543 rows x 1 columns]

# %%
y_train
# Out:
# 1332    0
# 2383    0
# 3685    1
# 1588    1
# 2049    0
#        ..
# 1648    0
# 488     0
# 3492    1
# 3808    1
# 149     0
# Name: male, Length: 1695, dtype: int64

# %%
y_test
# Out:
# 1523    0
# 1990    0
# 915     0
# 564     1
# 458     0
#        ..
# 2542    1
# 3735    0
# 1597    0
# 2369    0
# 802     0
# Name: male, Length: 2543, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-9e77cbe1d2c1> in <cell line: 3>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 model.fit(X_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
y_predicted = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-aae429bc2436> in <cell line: 1>()
# ----> 1 y_predicted = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     417         """
#     418         xp, _ = get_namespace(X)
# --> 419         scores = self.decision_function(X)
#     420         if len(scores.shape) == 1:
#     421             indices = xp.astype(scores > 0, int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     398         xp, _ = get_namespace(X)
#     399
# --> 400         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     401         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     402         return xp.reshape(scores, -1) if scores.shape[1] == 1 else scores
#
# ...

# %%
model.predict_proba(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-d905ae859022> in <cell line: 1>()
# ----> 1 model.predict_proba(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in predict_proba(self, X)
#    1365             self.multi_class == "auto"
#    1366             and (
# -> 1367                 self.classes_.size <= 2
#    1368                 or self.solver in ("liblinear", "newton-cholesky")
#    1369             )
#
# AttributeError: 'LogisticRegression' object has no attribute 'classes_'

# %%
model.score(X_test,y_test)
y_predicted
model.coef_
model.intercept_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e8cf87db86e3> in <cell line: 1>()
# ----> 1 model.score(X_test,y_test)
#       2 y_predicted
#       3 model.coef_
#       4 model.intercept_
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     666         from .metrics import accuracy_score
#     667
# --> 668         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     669
#     670     def _more_tags(self):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     417         """
#     418         xp, _ = get_namespace(X)
# --> 419         scores = self.decision_function(X)
#     420         if len(scores.shape) == 1:
#     421             indices = xp.astype(scores > 0, int)
#
# ...

# %%
y_predicted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9810194b0189> in <cell line: 1>()
# ----> 1 y_predicted
#
# NameError: name 'y_predicted' is not defined

# %%
model.coef_

# %%
model.intercept_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-925cf82d3ca8> in <cell line: 1>()
# ----> 1 model.intercept_
#
# AttributeError: 'LogisticRegression' object has no attribute 'intercept_'
