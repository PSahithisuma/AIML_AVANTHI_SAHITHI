# %% [markdown]
# <a href="https://colab.research.google.com/github/PSahithisuma/AIML_AVANTHI_SAHITHI/blob/main/Copy_of_English_Words_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Read the txt file into a dataframe

# %%
 df = pd.read_csv('/content/unix-words.txt')
 df
# Out:
#                  A
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 371907      zythem
# 371908      Zythia
# 371909      zythum
# 371910     Zyzomys
# 371911  Zyzzogeton
#
# [371912 rows x 1 columns]

# %% [markdown]
# Display the first 10 rows of the dataframe

# %%
df.head(10)
# Out:
#           A
# 0         a
# 1        aa
# 2       aal
# 3     aalii
# 4       aam
# 5      Aani
# 6  aardvark
# 7  aardwolf
# 8     Aaron
# 9   Aaronic

# %% [markdown]
# Change the column name 'A' to the words

# %%
df.rename(columns={'A':'Word'},inplace = True )
df
# Out:
#               Word
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 371907      zythem
# 371908      Zythia
# 371909      zythum
# 371910     Zyzomys
# 371911  Zyzzogeton
#
# [371912 rows x 1 columns]

# %% [markdown]
# Add character count of each word as another column in the dataframe

# %%
df['Word']=df['Word'].fillna('')
df['CharCount'] = df['Word'].apply(len)
df
# Out:
#               Word  CharCount
# 0                a          1
# 1               aa          2
# 2              aal          3
# 3            aalii          5
# 4              aam          3
# ...            ...        ...
# 371907      zythem          6
# 371908      Zythia          6
# 371909      zythum          6
# 371910     Zyzomys          7
# 371911  Zyzzogeton         10
#
# [371912 rows x 2 columns]

# %% [markdown]
# Add a column called value which is the sum of the numerical positions of the alphabets in the word
# (Ex: aah = 1 + 1 + 8 = 10)

# %%
def summing(Word):
  sum = 0
  Word.lower()
  for char in Word:
    s= ord(char)-96
    sum+=s
  return sum

df['values']=df['Word'].apply(summing)

# %% [markdown]
# Write a command to find the number of items in the dataframe

# %%
df.info
# Out:
# <bound method DataFrame.info of               Word  CharCount
# 0                a          1
# 1               aa          2
# 2              aal          3
# 3            aalii          5
# 4              aam          3
# ...            ...        ...
# 371907      zythem          6
# 371908      Zythia          6
# 371909      zythum          6
# 371910     Zyzomys          7
# 371911  Zyzzogeton         10
#
# [371912 rows x 2 columns]>

# %% [markdown]
# Set the words as the index of the dataframe

# %%
df.set_index('Word')
df
# Out:
#               Word  CharCount
# 0                a          1
# 1               aa          2
# 2              aal          3
# 3            aalii          5
# 4              aam          3
# ...            ...        ...
# 371907      zythem          6
# 371908      Zythia          6
# 371909      zythum          6
# 371910     Zyzomys          7
# 371911  Zyzzogeton         10
#
# [371912 rows x 2 columns]

# %% [markdown]
# What is the value of the word 'Acanthomeridae'?

# %%
df.loc[df['Word']=='Acanthomeridae']
# Out:
#                Word  CharCount
# 762  Acanthomeridae         14

# %% [markdown]
# What is the highest possible value for a word?

# %%
df.max()
# Out:
# Word         zythum
# CharCount        24
# dtype: object

# %% [markdown]
# What is the highest possible length of a word

# %%
df['CharCount'].max()
# Out:
# 24

# %% [markdown]
# What is the value of the word with Value '317'

# %%
df.loc[df['values'] == 317]
# Out:
#                             Word  CharCount  values
# 301795  thyroparathyroidectomize         24     317
# 339067  thyroparathyroidectomize         24     317

# %% [markdown]
# What is the most common value?

# %%
df['values'].mode()
# Out:
# 0    107
# Name: values, dtype: int64

# %% [markdown]
# What is the shortest word with the value of 107

# %%
df.loc[df['values'] ==107].min()
# Out:
# Word         Agriochoerus
# CharCount               5
# values                107
# dtype: object

# %% [markdown]
# Create a new column 'Ratio' such that ratio = value/char count

# %%
df['Ratio']= df['values'] /df['CharCount']
df
# Out:
#               Word  CharCount  values      Ratio
# 0                a          1       1   1.000000
# 1               aa          2       2   1.000000
# 2              aal          3      14   4.666667
# 3            aalii          5      32   6.400000
# 4              aam          3      15   5.000000
# ...            ...        ...     ...        ...
# 371907      zythem          6      97  16.166667
# 371908      Zythia          6      57   9.500000
# 371909      zythum          6     113  18.833333
# 371910     Zyzomys          7     117  16.714286
# 371911  Zyzzogeton         10     147  14.700000
#
# [371912 rows x 4 columns]

# %% [markdown]
# What is the maximum value of ratio?

# %%
df['Ratio'].max()
# Out:
# 26.0

# %% [markdown]
# What is the word with the highest ratio

# %%
df.loc[df['Ratio'] == 26].max()
# Out:
# Word            z
# CharCount       1
# values         26
# Ratio        26.0
# dtype: object

# %%
df.sort_values('Ratio', ascending = False)
# Out:
#          Word  CharCount  values  Ratio
# 370964      z          1      26   26.0
# 333692      z          1      26   26.0
# 333021      y          1      25   25.0
# 370293      y          1      25   25.0
# 332606  wuzzy          5     121   24.2
# ...       ...        ...     ...    ...
# 17095       B          1     -30  -30.0
# 122278                 0       0    NaN
# 128519                 0       0    NaN
# 221033                 0       0    NaN
# 227274                 0       0    NaN
#
# [371912 rows x 4 columns]

# %% [markdown]
# How many words have the ratio of 10

# %%
df['Ratio'].value_counts()
# Out:
#  12.000000    6951
#  11.000000    6328
#  13.000000    6246
#  10.000000    4629
#  14.000000    4429
#               ...
#  11.619048       1
# -23.000000       1
# -27.000000       1
#  7.611111        1
# -28.000000       1
# Name: Ratio, Length: 1780, dtype: int64

# %%
df.loc[df['Ratio'] == 10]
# Out:
#                Word  CharCount  values  Ratio
# 7          aardwolf          8      80   10.0
# 31         abaculus          8      80   10.0
# 198        abetment          8      80   10.0
# 329            ably          4      40   10.0
# 403        abounder          8      80   10.0
# ...             ...        ...     ...    ...
# 371433      Zolaist          7      70   10.0
# 371494  zoochemical         11     110   10.0
# 371762     zwieback          8      80   10.0
# 371771    Zygadenus          9      90   10.0
# 371904     Zyrenian          8      80   10.0
#
# [4629 rows x 4 columns]

# %% [markdown]
# What is the maximum value of all words with ratio as 10

# %%
df.loc[df['Ratio']==10].max()
# Out:
# Word         zwieback
# CharCount          21
# values            210
# Ratio            10.0
# dtype: object

# %%
df.query('Ratio == 10').max()
# Out:
# Word         zwieback
# CharCount          21
# values            210
# Ratio            10.0
# dtype: object

# %% [markdown]
# Of all the words with the value of 260, what has the loswest character count?

# %%
df.query('values == 260').min()
# Out:
# Word         chromophotolithograph
# CharCount                       17
# values                         260
# Ratio                    11.818182
# dtype: object
